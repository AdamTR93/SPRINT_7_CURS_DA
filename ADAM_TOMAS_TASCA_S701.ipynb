# %% [markdown]
# # NIVELL 1

# %% [markdown]
# **EXERCICI 1**

# %% [markdown]
# Calculadora de l'índex de massa corporal
#
# Escriu una funció que calculi l'IMC ingressat per l'usuari/ària, és a dir, qui ho executi haurà d'ingressar aquestes dades.

# %%
#Creamos las medidas que introducirá el usuario y la operación del IMC

peso = float(input('Pon tu peso en Kilogramos (Kg): '))
print('Tu peso es de', + peso ,'Kg')
altura = float(input('Pon tu altura en metros (m): '))
print('Tu atura es de', + altura, 'm')

IMC = peso/(altura**2)

print(f'Tu IMC es: {IMC:.2f}')

#Verifica el IMC y muestra el rango correspondiente

if IMC < 18.5:
    print('Estas bajo de peso')
elif 18.5<=IMC<=24.9:
    print('Tu peso es normal')
elif 25<=IMC<=29.9: 
    print('Tienes sobrepeso')
else:
    print('Tienes obesidad')
# Out:
# Su IMC es: 26.12
# Tienes sobrepeso

# %% [markdown]
# **EXERCICI 2**

# %% [markdown]
# Convertidor de temperatures.
#
# Existeixen diverses unitats de temperatura utilitzades en diferents contextos i regions. Les més comunes són Celsius (°C), Fahrenheit (°F) i Kelvin (K). També existeixen altres unitats com Rankine (°Ra) i Réaumur (°Re). Selecciona almenys 2 i construeix el convertidor.

# %%
def celsius_a_fahrenheit(celsius):
    return celsius*9/5 + 32
def celsius_a_kelvin(celsius):
    return celsius + 273.15
def kelvin_a_fahrenheit(kelvin):
    return (kelvin-273.15) *9/5 + 32
def kelvin_a_celsius(kelvin):
    return kelvin - 273.15
def fahrenheit_a_celsius(farenheit):
    return (farenheit-32) * 5/9
def fahrenheit_a_kelvin(farenheit):
    return (farenheit-32)* 5/9 + 273.15

def conversor_temp():
    print('Esto es un conversor de temperatura')
    print('Que temperatura quieres convertir?')
    print('1: De Celsius a Fahrenheit')
    print('2: De Celsius a kelvin')
    print('3: De kelvin a Celsius')
    print('4: De Kelvin a Fahrenheit')
    print('5: De Fahrenheit a Celsius')
    print('6: De Fahrenheit a Kelvin')

conversor_temp()
opcion= int(input('Elige una de las 6 opciones: '))
if opcion < 1 or opcion > 6:
    print('No existe esa opción')
else:
    temperatura = float(input('Ponga la temperatura que desea convertir: '))


if opcion == 1:
    resultado = celsius_a_fahrenheit(temperatura)
    print(f'{temperatura}ºC son {resultado: .2f}F')
elif opcion == 2:
    resultado = celsius_a_kelvin(temperatura)
    print(f'{temperatura}ºC son {resultado: .2f}K')
elif opcion == 3:
    resultado = kelvin_a_celsius(temperatura)
    print(f'{temperatura}K son {resultado: .2f}ºC')
elif opcion == 4:
    resultado = kelvin_a_fahrenheit(temperatura)
    print(f'{temperatura}K son {resultado: .2f}F')
elif opcion == 5:
    resultado = fahrenheit_a_celsius(temperatura)
    print(f'{temperatura}F son {resultado: .2f}ºC')
elif opcion == 6:
    resultado= fahrenheit_a_kelvin(temperatura)
    print(f'{temperatura}F son {resultado: .2f}K')
# Out:
# Esto es un conversor de temperatura
# Que temperatura quieres convertir?
# 1: De Celsius a Fahrenheit
# 2: De Celsius a kelvin
# 3: De kelvin a Celsius
# 4: De Kelvin a Fahrenheit
# 5: De Fahrenheit a Celsius
# 6: De Fahrenheit a Kelvin
# No existe esa opción

# %% [markdown]
# **EXERCICI 3**
#
# Comptador de paraules d'un text.
#
# Escriu una funció que donat un text, mostri les vegades que apareix cada paraula.

# %%
from collections import Counter

text = input("escribe tu texto: \n")
punct_signs = ".,?!¿¡()"
translator = str.maketrans(punct_signs, " " * len(punct_signs))
text = text.translate(translator).lower()
words = Counter(text.split())
for palabra,numero in words.items():
    
    print(f'{palabra} : {numero}')
# Out:
# un : 3
# texto : 1
# es : 2
# una : 3
# composición : 2
# de : 5
# signos : 1
# codificados : 1
# en : 1
# sistema : 1
# escritura : 1
# que : 2
# forma : 1
# unidad : 1
# sentido : 2
# también : 1
# caracteres : 1
# imprimibles : 1
# generados : 1
# por : 1
# algoritmo : 1
# cifrado : 1
# aunque : 1
# no : 1
# tienen : 1
# para : 1
# cualquier : 1
# persona : 1

# %% [markdown]
# **EXERCICI 4**
#
# Diccionari invers.
#
# Resulta que el client té una enquesta molt antiga que s'emmagatzema en un diccionari i els resultats els necessita al revés, és a dir, intercanviats les claus i els valors. Els valors i claus en el diccionari original són únics; si aquest no és el cas, la funció hauria d'imprimir un missatge d'advertiment.

# %%
def diccionario_inverso(d):
    # Comprobamos si los valores son únicos
    if len(d) != len(set(d.values())):
        print("Advertència: Els valors del diccionari no són únics.")
        return None

    # Intercambiamos las claves por los valores
    invers = {valor: clau for clau, valor in d.items()}
    return invers

# Ponemos un ejemplo de diccionario sin duplicados
diccionario_original = {
    'a': 1,
    'b': 2,
    'c': 3
}

# Cridar a la funció i obtenir el diccionari invers
diccionario_inverso_resultado = diccionario_inverso(diccionario_original)


# Mostrar el resultat si no és None
if diccionario_inverso_resultado:
    print("Diccionari invers:")
    print(diccionario_inverso_resultado)
# Out:
# Diccionari invers:
# {1: 'a', 2: 'b', 3: 'c'}
